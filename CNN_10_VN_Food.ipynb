# %% [markdown]
# <a href="https://colab.research.google.com/github/joethecoolest/Bai_Tap_AI/blob/main/CNN_10_VN_Food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# ! rm -rf /content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_beo
# ! rm -rf /content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_canh
# ! rm -rf /content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_xeo
# ! rm -rf /content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_bo_hue

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from bing_image_downloader import downloader
downloader.download("phở",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/pho')
downloader.download("bún bò huế",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/bun_bo_hue')
downloader.download("bún riêu",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/bun_rieu')
downloader.download("bún thịt nướng",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/bun_thit_nuong')
downloader.download("bánh canh",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/banh_canh')
downloader.download("bánh xèo",limit=10,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/banh_xeo')
downloader.download("bánh bèo",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/banh_beo')
downloader.download("cơm tấm",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/com_tam')
downloader.download("hột vịt lộn",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/hot_vit_lon')
downloader.download("canh chua",limit=80,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train/canh_chua')
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 180, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/req_command.py", line 199, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 385, in run
#     conflicts = self._determine_conflicts(to_install)
# ...

# %%
from bing_image_downloader import downloader
downloader.download("phở",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/pho')
downloader.download("bún bò huế",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_bo_hue')
downloader.download("bún riêu",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_rieu')
downloader.download("bún thịt nướng",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_thit_nuong')
downloader.download("bánh canh",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_canh')
downloader.download("bánh xèo",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_xeo')
downloader.download("bánh bèo",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_beo')
downloader.download("cơm tấm",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/com_tam')
downloader.download("hột vịt lộn",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/hot_vit_lon')
downloader.download("canh chua",limit=1,output_dir='/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/canh_chua')
# Out:
# [%] Downloading Images to /content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/pho/phở
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://static.riviu.co/image/2020/08/12/0668c1cf4e3b77d2aa1b34c9d134a1fe.jpeg
# [Error]Invalid image, not saving https://static.riviu.co/image/2020/08/12/0668c1cf4e3b77d2aa1b34c9d134a1fe.jpeg
#
# [!] Issue getting: https://static.riviu.co/image/2020/08/12/0668c1cf4e3b77d2aa1b34c9d134a1fe.jpeg
# [!] Error:: Invalid image, not saving https://static.riviu.co/image/2020/08/12/0668c1cf4e3b77d2aa1b34c9d134a1fe.jpeg
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ...
#
# [%] Downloading Image #1 from https://www.trbimg.com/img-580fa68c/turbine/la-1477420909-snap-photo/
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# [%] Downloading Images to /content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_bo_hue/bún bò huế
#
#
# [!!]Indexing page: 1
#
# ...

# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
training_data=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train',
                                               target_size=(150,150),
                                               batch_size=32,
                                               class_mode ='categorical')
validation_data=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/validation',
                                               target_size=(150,150),
                                               batch_size=32,
                                               class_mode ='categorical')
# Out:
# Found 789 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
kieuhinh=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_data=kieuhinh.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 789 images belonging to 10 classes.

# %%
validation_data=kieuhinh.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 100 images belonging to 10 classes.

# %%
training_data.class_indices
# Out:
# {'banh_beo': 0,
#  'banh_canh': 1,
#  'banh_xeo': 2,
#  'bun_bo_hue': 3,
#  'bun_rieu': 4,
#  'bun_thit_nuong': 5,
#  'canh_chua': 6,
#  'com_tam': 7,
#  'hot_vit_lon': 8,
#  'pho': 9}

# %%
model=Sequential()
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer = 'he_uniform'))
#model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 150, 150, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        36896
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 43808)             0
#
#  dense (Dense)               (None, 128)               5607552
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 5,649,322
# Trainable params: 5,649,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
callbacks=[EarlyStopping(monitor='val_loss',patience=20)]
history=model.fit(training_data,
                  steps_per_epoch=len(training_data),
                  batch_size = 64,
                  epochs=100,
                  validation_data=validation_data,
                  validation_steps=len(validation_data),
                  callbacks=callbacks,
                  verbose = 1)
# Out:
# Epoch 1/100
# 20/25 [=======================>......] - ETA: 58s - loss: 4.7893 - accuracy: 0.1145
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 25/25 [==============================] - 331s 13s/step - loss: 4.2851 - accuracy: 0.1115 - val_loss: 2.3017 - val_accuracy: 0.1100
# Epoch 2/100
# 25/25 [==============================] - 29s 1s/step - loss: 2.3028 - accuracy: 0.0963 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/100
# 25/25 [==============================] - 29s 1s/step - loss: 2.3028 - accuracy: 0.0837 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/100
# 25/25 [==============================] - 29s 1s/step - loss: 2.3024 - accuracy: 0.1027 - val_loss: 2.3025 - val_accuracy: 0.0800
# Epoch 5/100
# ...

# %%
#đánh giá chất lượng của mô hình và vẽ lại
score = model.evaluate(validation_data,verbose=0)
print('Sai số kiểm tra là: ',score[0])
print('Độ chính xác kiểm tra là: ',score[1])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# Sai số kiểm tra là:  0.6102844476699829
# Độ chính xác kiểm tra là:  0.9100000262260437
# <function matplotlib.pyplot.show>

# %%
model.save("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/CNN_10_VN_Food.h5")

# %%
from tensorflow.keras.models import load_model
model=load_model('/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/CNN_10_VN_Food.h5')

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_beo/bánh bèo/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# banh_beo

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_canh/bánh canh/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# banh_canh

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/banh_xeo/bánh xèo/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# banh_xeo

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_bo_hue/bún bò huế/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# bun_bo_hue

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_rieu/bún riêu/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# bun_rieu

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/bun_thit_nuong/bún thịt nướng/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# bun_thit_nuong

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/canh_chua/canh chua/Image_1.png",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# canh_chua

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/com_tam/cơm tấm/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# com_tam

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/hot_vit_lon/hột vịt lộn/Image_1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# hot_vit_lon

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/test/pho/phở/download.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='banh_beo'
if round(result[0][1])==1:
  prediction='banh_canh'
if round(result[0][2])==1:
  prediction='banh_xeo'
if round(result[0][3])==1:
  prediction='bun_bo_hue'
if round(result[0][4])==1:
  prediction='bun_rieu'
if round(result[0][5])==1:
  prediction='bun_thit_nuong'
if round(result[0][6])==1:
  prediction='canh_chua'
if round(result[0][7])==1:
  prediction='com_tam'
if round(result[0][8])==1:
  prediction='hot_vit_lon'
if round(result[0][9])==1:
  prediction='pho'
print(prediction)
# Out:
# pho

# %%
from tensorflow.keras.models import load_model
model=load_model('/content/drive/MyDrive/Colab Notebooks/CNN_10_VN_food/CNN_10_VN_Food.h5')
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
